# %%
import pandas as pd
import numpy as np

# %%
nilai=pd.DataFrame([70,80,90],
                   index=['A','B','C'],
                   columns=['Nilai'])

# %%
nilai.loc['A','Nilai']#index, kolom
# Out:
# 70

# %%
nilai.iloc[1,0]#index,kolom
# Out:
# 80

# %%
dataset = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
dataset[(dataset['housing_median_age'] < 20) &
        dataset['population']<100]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
dataset.query("housing_median_age < 20 and population <100")
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 483     -115.90     32.69                18.0        414.0            86.0
# 495     -122.29     37.82                 2.0        158.0            43.0
# 842     -117.95     35.08                 1.0         83.0            15.0
# 871     -117.84     33.76                16.0        238.0            51.0
# 1018    -121.28     38.53                18.0        224.0            38.0
# 1050    -121.96     37.74                 2.0        200.0            20.0
# 1094    -120.33     39.30                16.0        868.0           178.0
# 1115    -116.95     33.86                 1.0          6.0             2.0
# 1539    -120.79     37.08                 9.0         97.0            20.0
# 1726    -117.05     33.03                16.0         87.0            20.0
# 1902    -117.90     36.95                19.0         99.0            26.0
# ...

# %%
dataset.sort_values(by='housing_median_age',ascending=False)#mengurutkan dari nilai terbesar
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2507    -118.15     33.77                52.0       2204.0           498.0
# 1865    -122.28     37.90                52.0       2003.0           250.0
# 541     -117.18     32.76                52.0       2023.0           301.0
# 2876    -122.50     37.77                52.0       2299.0           441.0
# 306     -122.65     38.23                52.0       1735.0           347.0
# ...         ...       ...                 ...          ...             ...
# 2117    -117.51     34.16                 2.0        718.0            98.0
# 1271    -120.98     37.59                 2.0       5042.0           834.0
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
# 1115    -116.95     33.86                 1.0          6.0             2.0
# 842     -117.95     35.08                 1.0         83.0            15.0
#
#       population  households  median_income  median_house_value
# ...

# %%
dataset.sort_values(by=['housing_median_age','population'],
                    ascending=[False,True])
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 740     -117.12     32.66                52.0         16.0             4.0
# 1355    -117.11     32.66                52.0         25.0             5.0
# 676     -118.25     34.09                52.0        104.0            20.0
# 1509    -119.02     35.38                52.0         90.0            35.0
# 894     -122.39     37.74                52.0        126.0            24.0
# ...         ...       ...                 ...          ...             ...
# 1271    -120.98     37.59                 2.0       5042.0           834.0
# 2452    -117.64     33.87                 2.0      17470.0          2727.0
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
# 1115    -116.95     33.86                 1.0          6.0             2.0
# 842     -117.95     35.08                 1.0         83.0            15.0
#
#       population  households  median_income  median_house_value
# ...
